# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl

import sys, os
src_path = os.path.abspath(os.path.join("..", "src"))
if src_path not in sys.path:
    sys.path.insert(0, src_path)
import config as co


with open(co.DATA_PATH + co.PROCESS_SAMPLES, "rb") as file:
            sample = pkl.load(file)

# %%
sample.keys()
# Out:
# dict_keys(['CG4_Gals', 'Control4B_Gals', 'Control4C_Gals', 'RG4_Gals', 'CG4_Groups', 'Control4B_Groups', 'Control4C_Groups', 'RG4_Groups', 'SDSS'])

# %%
sample['SDSS'][['objid','morphology']].head
# Out:
# <bound method NDFrame.head of                      objid  morphology
# 0      1237650795683709164  Elliptical
# 2      1237651800161321210      Spiral
# 3      1237648722831343722      Spiral
# 4      1237651801774358588      Spiral
# 5      1237648721757929604      Spiral
# ...                    ...         ...
# 69990  1237657857137246551      Spiral
# 69991  1237665535468699895      Spiral
# 69992  1237665372260532810      Spiral
# 69993  1237665536543031693      Spiral
# 69994  1237665231596159466  Elliptical
#
# [52531 rows x 2 columns]>

# %%
sample['Control4C_Gals'][['objid','morphology']].head
# Out:
# <bound method NDFrame.head of                     objid morphology
# 0      346787094795937792  Uncertain
# 1      346783246505240576  Uncertain
# 2      346785995284310016  Uncertain
# 3      346786545040123904  Uncertain
# 4      349090577159055360  Uncertain
# ...                   ...        ...
# 3003  1382642514766358528  Uncertain
# 3004  4544273950440091648  Uncertain
# 3005  4544272576050556928  Uncertain
# 3006   596769040937019392  Uncertain
# 3007   596769315814926336  Uncertain
#
# [3008 rows x 2 columns]>

# %%
sample['SDSS'].loc[sample['SDSS']['objid'].isin(
    sample['Control4C_Gals']['objid'])]
# Out:
# Empty DataFrame
# Columns: [specObjID, z, r_obs, objid, SFR, sSFR, lgm, h_alpha_eqw, h_beta_eqw, oiii_5007_eqw, nii_6584_eqw, h_alpha_flux, h_beta_flux, oiii_5007_flux, nii_6584_flux, p_E, p_S, log_NII_Ha, log_OIII_Hb, is_AGN, morphology, sSFR_status, sSFR_raw]
# Index: []
#
# [0 rows x 23 columns]

# %%
sample['SDSS'].loc[sample['SDSS']['objid'].isin(
    sample['Control4B_Gals']['objid'])]
# Out:
#                  specObjID         z     r_obs                objid       SFR  \
# 4       307486430999898112  0.028872  15.90264  1237651801774358588 -0.404741
# 23      344688951312803840  0.030401  13.31211  1237648705129349140 -1.226143
# 101     307497700994082816  0.028635  17.08557  1237648721757929589 -0.576025
# 102     307499625139431424  0.028862  17.42095  1237654670812774549 -1.063060
# 117     345819799458179072  0.033371  16.42030  1237648705667072024 -0.182327
# ...                    ...       ...       ...                  ...       ...
# 69774  3092879550707689472  0.041227  17.02706  1237668349211050186 -0.385772
# 69787  3105233118466959360  0.044578  16.56550  1237668297142304954 -1.489952
# 69802  3125516634618357760  0.042900  15.41159  1237667782850052288 -1.551079
# 69937  3141341630615808000  0.042902  16.66278  1237667736134484127 -0.222071
# 69956  3141298474784417792  0.039917  16.95430  1237667783387185352 -0.343798
#
# ...
